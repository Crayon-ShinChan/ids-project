# %%
import pandas as pd

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import Perceptron
from sklearn.linear_model import SGDClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
data = pd. read_csv("WA_Fn-UseC_-Telco-Customer-Churn.csv")

# %%
data.head(6)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
# 5  9305-CDSKC  Female              0      No         No       8          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# ...

# %%
data.shape
# Out:
# (7043, 21)

# %%
data.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
data.tail(10)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 7033  9767-FFLEM    Male              0      No         No      38
# 7034  0639-TSIQW  Female              0      No         No      67
# 7035  8456-QDAVC    Male              0      No         No      19
# 7036  7750-EYXWZ  Female              0      No         No      12
# 7037  2569-WGERO  Female              0      No         No      72
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 7033          Yes                No     Fiber optic                   No  ...
# ...

# %%
print("hello,world")
# Out:
# hello,world

# %%
grid = sns. FacetGrid(data,col='Churn',row='gender',size=3,aspect=1.6)
grid.map(plt.hist,'MonthlyCharges',alpha=.5,bins=100)
grid.add_legend;
# Out:
# /Users/liyunfan/opt/anaconda3/lib/python3.8/site-packages/seaborn/axisgrid.py:243: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
g = sns.FacetGrid(data,col="Churn")
g.map(plt.hist,'MonthlyCharges',bins=300)

# %%
X = data.drop("Churn",axis = 1)
Y = data["Churn"]

X.shape,Y.shape
# Out:
# ((7043, 20), (7043,))

# %%
import numpy as np
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(
X, Y, test_size=0.33, random_state=42)

# %%
X_train
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 298   2985-JUUBZ    Male              0     Yes        Yes      40
# 3318  5016-ETTFF    Male              0      No         No      10
# 5586  1998-VHJHK  Female              0      No         No      27
# 6654  1925-TIBLE  Female              0     Yes         No       7
# 5362  0485-ZBSLN    Male              0     Yes        Yes      65
# ...          ...     ...            ...     ...        ...     ...
# 3772  0684-AOSIH    Male              0     Yes         No       1
# 5191  5982-PSMKW  Female              0     Yes        Yes      23
# 5226  8044-BGWPI    Male              0     Yes        Yes      12
# 5390  7450-NWRTR    Male              1      No         No      12
# 860   4795-UXVCJ    Male              0      No         No      26
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  \
# 298           Yes               Yes             DSL                   No
# ...

# %%
logreg = LogisticRegression()
logreg.fit(X_train, Y_train)
Y_pred = logreg.predict(X_test)
acc_log = round(logreg.score(X_train, Y_train))
acc_log
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-a28f93d656ec> in <module>
#       1 logreg = LogisticRegression()
# ----> 2 logreg.fit(X_train, Y_train)
#       3 Y_pred = logreg.predict(X_test)
#       4 acc_log = round(logreg.score(X_train, Y_train))
#       5 acc_log
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py in fit(self, X, y, sample_weight)
#    1340             _dtype = [np.float64, np.float32]
#    1341
# -> 1342         X, y = self._validate_data(X, y, accept_sparse='csr', dtype=_dtype,
#    1343                                    order="C",
#    1344                                    accept_large_sparse=solver != 'liblinear')
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
# ...
